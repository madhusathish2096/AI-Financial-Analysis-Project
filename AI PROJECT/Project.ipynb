# %% [markdown]
# #        **AI COMPANY’S FINANCIAL ANALYSIS (2015 - 2024)**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Genie\Downloads\AI_Financial.csv")
df
# Out:
#              Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0      2015-01-01  OpenAI                 5.92               0.63
# 1      2015-01-02  OpenAI                 5.41               1.81
# 2      2015-01-03  OpenAI                 4.50               0.61
# 3      2015-01-04  OpenAI                 5.45               0.95
# 4      2015-01-05  OpenAI                 3.40               1.48
# ...           ...     ...                  ...                ...
# 10954  2024-12-27    Meta               100.19             103.54
# 10955  2024-12-28    Meta                99.12             102.37
# 10956  2024-12-29    Meta                98.95             103.11
# 10957  2024-12-30    Meta               100.74             103.21
# 10958  2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%
# 0                   -36.82   NaN           -0.36
# 1                    80.59   NaN            0.41
# 2                   -38.88   NaN            0.23
# 3                    -5.34   NaN            0.93
# 4                    48.45   NaN           -0.09
# ...                    ...   ...             ...
# 10954               417.68   NaN           -0.66
# 10955               411.86   NaN           -0.57
# 10956               415.54   NaN           -0.52
# 10957               416.03   NaN            0.22
# 10958               417.04   NaN           -0.16
#
# [10959 rows x 7 columns]

# %%
# Show Data Types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10959 entries, 0 to 10958
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10959 non-null  object
#  1   Company              10959 non-null  object
#  2   R&D_Spending_USD_Mn  10959 non-null  float64
#  3   AI_Revenue_USD_Mn    10959 non-null  float64
#  4   AI_Revenue_Growth_%  10959 non-null  float64
#  5   Event                233 non-null    object
#  6   Stock_Impact_%       10959 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 599.4+ KB

# %%
# Statistical summary

df.describe()
# Out:
#        R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  AI_Revenue_Growth_%  \
# count         10959.000000       10959.000000         10959.000000
# mean             65.184504          44.126571           159.395988
# std              47.918247          41.639356           135.462185
# min               1.570000          -0.550000          -155.430000
# 25%               8.640000           3.610000            43.870000
# 50%              70.960000          35.220000           133.750000
# 75%              99.600000          71.680000           258.300000
# max             163.830000         155.960000           565.500000
#
#        Stock_Impact_%
# count    10959.000000
# mean         0.025560
# std          0.749513
# min         -3.000000
# 25%         -0.500000
# 50%          0.000000
# 75%          0.510000
# max         18.500000

# %%
# Convert Datatype of Date column into Datetime format

df['Date'] = pd.to_datetime(df['Date'])

# %%
# Check Missing Values

df.isnull().sum()
# Out:
# Date                       0
# Company                    0
# R&D_Spending_USD_Mn        0
# AI_Revenue_USD_Mn          0
# AI_Revenue_Growth_%        0
# Event                  10726
# Stock_Impact_%             0
# dtype: int64

# %%
# Fill Missing Values

df['Event'].fillna('No Event',inplace = True)
# Out:
# C:\Users\Genie\AppData\Local\Temp\ipykernel_2176\2482631519.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Event'].fillna('No Event',inplace = True)

# %%
# Check Null Values After Using Fillna Method

df.isnull().sum()
# Out:
# Date                   0
# Company                0
# R&D_Spending_USD_Mn    0
# AI_Revenue_USD_Mn      0
# AI_Revenue_Growth_%    0
# Event                  0
# Stock_Impact_%         0
# dtype: int64

# %%
# Show company Names

df['Company'].unique()
# Out:
# array(['OpenAI', 'Google', 'Meta'], dtype=object)

# %%
# Create new column for 'Year'

df['Year'] = df['Date'].dt.year
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_%     Event  Stock_Impact_%  Year
# 0               -36.82  No Event           -0.36  2015
# 1                80.59  No Event            0.41  2015
# 2               -38.88  No Event            0.23  2015
# 3                -5.34  No Event            0.93  2015
# 4                48.45  No Event           -0.09  2015

# %%
# Create new column for 'Month'

df['Month_Name'] = df['Date'].dt.month_name()
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_%     Event  Stock_Impact_%  Year Month_Name
# 0               -36.82  No Event           -0.36  2015    January
# 1                80.59  No Event            0.41  2015    January
# 2               -38.88  No Event            0.23  2015    January
# 3                -5.34  No Event            0.93  2015    January
# 4                48.45  No Event           -0.09  2015    January

# %%
# Exploratory Data Analysis (EDA)
# Revenue Distribution

plt.hist(df['AI_Revenue_USD_Mn'])
plt.title("AI Revenue Distribution")
plt.xlabel("Revenue (USD Mn)")
plt.ylabel("Count")
plt.show()

# %%
# R&D Expenses Distribution

plt.hist(df['R&D_Spending_USD_Mn'])
plt.title("Expenses Distribution")
plt.xlabel("Expenses (USD Mn)")
plt.ylabel("Count")
plt.show()

# %%
# Revenue Growth Percentage Distribution

plt.hist(df['AI_Revenue_Growth_%'])
plt.title("Revenue Growth Percentage Distribution")
plt.xlabel("Growth (%)")
plt.ylabel("Frequency")
plt.show()

# %%
# How much amount companies Expenses on R&D

# Convert Million USD to Billion USD
print("Companies Expenses for R&D in Billion USD")
RD = df.groupby('Company')['R&D_Spending_USD_Mn'].sum()/1000
RD
# Out:
# Companies Expenses for R&D in Billion USD
# Company
# Google    423.34114
# Meta      264.53307
# OpenAI     26.48277
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
# Bar plot to show the amount spent on R&D by companies 

plt.figure(figsize=(4, 4))
plt.bar(RD.index,RD.values, color= ['SkyBlue'])
plt.title('R&D Expenses by the companies')
plt.xlabel('Company')
plt.ylabel('Amount in USD')
plt.show()

# %%
# Revenue Earned by the companies 

# Convert Million USD to Billion USD
print("Companies AI Revenue in Billion USD")
REV = df.groupby('Company')['AI_Revenue_USD_Mn'].sum()/1000
REV
# Out:
# Companies AI Revenue in Billion USD
# Company
# Google    284.49838
# Meta      189.62182
# OpenAI      9.46289
# Name: AI_Revenue_USD_Mn, dtype: float64

# %%
# Bar plot to show the Revenue by companies 

plt.figure(figsize=(4, 4))
plt.barh(REV.index,REV.values, color= ['Violet'])
plt.title('Companies Revenue in Billion USD')
plt.xlabel('Amount in Billion USD')
plt.ylabel('Company')
plt.show()

# %%
# Subplot

plt.figure(figsize =(10,5))
plt.subplot(1,2,1)
plt.bar(RD.index,RD.values, color= ['SkyBlue'])
plt.title('R&D spending by the companies')
plt.xlabel('Company')
plt.ylabel('Amount in USD')

plt.subplot(1,2,2)

plt.barh(REV.index,REV.values, color= ['Violet'])
plt.title('Companies Revenue in Billion USD')
plt.xlabel('Amount in Billion USD')
plt.ylabel('Company')
plt.show()

# %%
# Yearwise Impact on the Stock

plt.figure(figsize = (10,5))
plt.plot(df['Year'],df['Stock_Impact_%'],color = 'Green')
plt.title('Stock impact')
plt.xlabel('Year')
plt.ylabel('Stock_Impact_%')
plt.show()

# %%
data_OpenAI = df[df['Company'] == 'OpenAI']

# %%
data_Google = df[df['Company'] == 'Google']

# %%
data_Meta = df[df['Company'] == 'Meta']
data_Company = df[df['Company'].isin(['OpenAI','Google','Meta'])]

# %%
# Line plot to show the stock value of companies Yearwsie 

plt.figure(figsize = (10,5))
plt.plot(data_Company['Date'],data_Company['Stock_Impact_%'])
plt.title('Companies Stock value')
plt.xlabel("Date('Year')")
plt.ylabel('Stock_Impact_%')
plt.grid(True)
plt.show()

# %%
# Scatterplot AI Revenue growth of the company

sns.scatterplot(x ='Date',y = "AI_Revenue_Growth_%",data = df,hue = 'Company')
plt.title('AI Revenue Growth')
plt.show()

# %%
# Pie chart of Stock Impact by Companywise

data = df.groupby('Company')['Stock_Impact_%'].sum()

plt.figure(figsize =(5,5))
plt.pie( data,labels = data.index ,autopct='%1.1f%%')
plt.title("Stock Impact by Companywise")
plt.show()

# %%
# OpenAI Revenue Growth Year by Year

plt.plot(data_OpenAI['Date'],data_OpenAI['AI_Revenue_Growth_%'],color= 'lightpink')
plt.title ('OpenAI Revenue Growth Yearwise')
plt.show()

# %%
# Google Revenue Growth Year by Year

plt.plot(data_Google['Date'],data_Google['AI_Revenue_Growth_%'],color= 'm')
plt.title ('Google Revenue Growth Yearwise')

plt.show()

# %%
# Meta Revenue Growth Year by Year

plt.plot(data_Meta['Date'],data_Meta['AI_Revenue_Growth_%'],color= 'c')
plt.title ('Meta Revenue Growth Yearwise')

plt.show()

# %%
# Heatmap

plt.figure(figsize=(10,5))
sns.heatmap(df.corr(numeric_only=True), cmap='tab10', annot=True, fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %%
# Seaborn Pairplot to show the relations between the columns

sns.pairplot(df);

# %%
# Maximum Stock impact on companies & Year

stocks = df.groupby(['Year','Company'])['Stock_Impact_%'].max()

stocks
# Out:
# Year  Company
# 2015  Google      4.96
#       Meta        4.80
#       OpenAI      3.92
# 2016  Google      6.20
#       Meta        2.14
#       OpenAI      4.66
# 2017  Google      4.42
#       Meta        4.21
#       OpenAI      4.63
# 2018  Google      1.97
#       Meta        4.54
#       OpenAI      4.94
# 2019  Google      3.20
#       Meta        1.86
#       OpenAI      4.20
# 2020  Google      4.18
#       Meta        4.86
#       OpenAI      8.50
# 2021  Google      4.10
#       Meta        4.80
#       OpenAI      7.20
# 2022  Google      4.88
#       Meta        3.98
#       OpenAI     12.00
# 2023  Google      5.80
#       Meta        6.80
#       OpenAI     15.20
# 2024  Google      2.89
#       Meta        7.40
#       OpenAI     18.50
# Name: Stock_Impact_%, dtype: float64

# %%
# Bar Plot for Maximum Stock impact on companies & Year

stocks.plot(kind = 'bar',color = ['GREEN','PINK','SKYBLUE'])
plt.title("Maximum Stock impact on companies & Year")

plt.show()

# %%
# Area Chart for Companies Spending R&D in USD_Mn

data = df.groupby('Company')['R&D_Spending_USD_Mn'].sum()

plt.fill_between(data.index,data.values, color= "lightblue")
plt.xlabel('Company')
plt.ylabel('R&D_Spending_USD_Mn')
plt.title("Companies Spending R&D in USD_Mn")
plt.show()

# %%
# HeatMap for Revenue Growth and Stock Impact

corr_data = df[['AI_Revenue_Growth_%', 'Stock_Impact_%']]
corr_matrix = corr_data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation between AI Revenue Growth and Stock Impact')
plt.show()

# %%
# Daily Average stock impact of the companies

df.groupby('Company')['Stock_Impact_%'].mean()*100
# Out:
# Company
# Google    2.620860
# Meta      0.976184
# OpenAI    4.070901
# Name: Stock_Impact_%, dtype: float64

# %%
# Daily Average Expenses on R&D by the companies

df.groupby('Company')['R&D_Spending_USD_Mn'].mean()
# Out:
# Company
# Google    115.888623
# Meta       72.415294
# OpenAI      7.249595
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
# Maximum impact % on a company Stocks

df.groupby('Company')['Stock_Impact_%'].max()
# Out:
# Company
# Google     6.2
# Meta       7.4
# OpenAI    18.5
# Name: Stock_Impact_%, dtype: float64

# %%
# Maximum Revenue Growth Percentage

df.sort_values(by= 'AI_Revenue_Growth_%', ascending =False)
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3423 2024-05-16  OpenAI                 8.47               6.65
# 3612 2024-11-21  OpenAI                10.16               6.59
# 3627 2024-12-06  OpenAI                 8.51               6.49
# 3645 2024-12-24  OpenAI                 8.79               6.46
# 3508 2024-08-09  OpenAI                 9.92               6.33
# ...         ...     ...                  ...                ...
# 98   2015-04-09  OpenAI                 4.80              -0.25
# 548  2016-07-02  OpenAI                 5.19              -0.29
# 649  2016-10-11  OpenAI                 5.37              -0.35
# 205  2015-07-25  OpenAI                 5.23              -0.42
# 189  2015-07-09  OpenAI                 5.66              -0.55
#
#       AI_Revenue_Growth_%     Event  Stock_Impact_%  Year Month_Name
# 3423               565.50  No Event            0.51  2024        May
# 3612               558.70  No Event            0.63  2024   November
# 3627               548.83  No Event           -0.15  2024   December
# 3645               546.07  No Event            0.45  2024   December
# 3508               532.86  No Event            0.77  2024     August
# ...                   ...       ...             ...   ...        ...
# 98                -125.50  No Event           -0.56  2015      April
# 548               -129.11  No Event           -0.31  2016       July
# 649               -135.31  No Event            0.12  2016    October
# 205               -141.61  No Event           -0.62  2015       July
# 189               -155.43  No Event            0.70  2015       July
#
# [10959 rows x 9 columns]

# %%
# Maximum Stock Impact on OpenAI Events

data_OpenAI.sort_values(by = 'Stock_Impact_%' ,ascending = False)
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3408 2024-05-01  OpenAI                10.91               5.34
# 2994 2023-03-14  OpenAI                 7.78               4.05
# 2890 2022-11-30  OpenAI                10.60               3.18
# 2652 2022-04-06  OpenAI                 9.24               3.48
# 1988 2020-06-11  OpenAI                 5.90               2.62
# ...         ...     ...                  ...                ...
# 3590 2024-10-30  OpenAI                11.05               5.27
# 1212 2018-04-27  OpenAI                 5.38               1.76
# 1303 2018-07-27  OpenAI                 7.44               0.97
# 2480 2021-10-16  OpenAI                 8.39               2.78
# 3350 2024-03-04  OpenAI                10.82               4.77
#
#       AI_Revenue_Growth_%                        Event  Stock_Impact_%  Year  \
# 3408               434.27    GPT-5 release (predicted)           18.50  2024
# 2994               304.57                GPT-4 release           15.20  2023
# 2890               217.72     ChatGPT (GPT-3.5) launch           12.00  2022
# 2652               247.93             DALL·E 2 release            9.80  2022
# 1988               161.56                GPT-3 release            8.50  2020
# ...                   ...                          ...             ...   ...
# 3590               427.50     AI-powered search update           -2.52  2024
# 1212                76.47      AI ethics policy update           -2.70  2018
# 1303                -2.63     AI-powered search update           -2.95  2018
# 2480               178.28  AI Ads Optimization upgrade           -2.98  2021
# 3350               376.53  AI Ads Optimization upgrade           -3.00  2024
#
#      Month_Name
# 3408        May
# 2994      March
# 2890   November
# 2652      April
# 1988       June
# ...         ...
# 3590    October
# 1212      April
# 1303       July
# 2480    October
# 3350      March
#
# [3653 rows x 9 columns]

# %%
# Maximum Stock Impact on Google Events

data_Google.sort_values(by = 'Stock_Impact_%' ,ascending = False)
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 4092 2016-03-15  Google                84.56              36.22
# 6914 2023-12-06  Google               146.59             129.17
# 6654 2023-03-21  Google               149.34             129.76
# 3883 2015-08-19  Google                79.27              30.89
# 6388 2022-06-28  Google               137.71             107.96
# ...         ...     ...                  ...                ...
# 4122 2016-04-14  Google                87.19              36.08
# 4412 2017-01-29  Google                92.21              43.25
# 6303 2022-04-04  Google               138.00             106.81
# 3803 2015-05-31  Google                81.14              29.30
# 5479 2020-01-01  Google               117.24              74.82
#
#       AI_Revenue_Growth_%                            Event  Stock_Impact_%  \
# 4092                20.73          AlphaGo beats Lee Sedol            6.20
# 6914               330.55                Gemini AI release            5.80
# 6654               332.53              Bard chatbot launch            5.00
# 3883                 2.98              AI partnership deal            4.96
# 6388               259.85          AI ethics policy update            4.88
# ...                   ...                              ...             ...
# 4122                20.28              AI partnership deal           -2.67
# 4412                44.17      AI Ads Optimization upgrade           -2.68
# 6303               256.04  AI Video Recommendation upgrade           -2.80
# 3803                -2.32                  Cloud AI launch           -2.87
# 5479               149.41              AI partnership deal           -2.93
#
#       Year Month_Name
# 4092  2016      March
# 6914  2023   December
# 6654  2023      March
# 3883  2015     August
# 6388  2022       June
# ...    ...        ...
# 4122  2016      April
# 4412  2017    January
# 6303  2022      April
# 3803  2015        May
# 5479  2020    January
#
# [3653 rows x 9 columns]

# %%
# Maximum Stock Impact on Meta Events

data_Meta.sort_values(by = 'Stock_Impact_%' ,ascending = False)
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 10731 2024-05-18    Meta               103.64             103.05
# 10426 2023-07-18    Meta                92.44              85.67
# 10282 2023-02-24    Meta                93.71              86.98
# 9156  2020-01-25    Meta                72.73              49.10
# 7526  2015-08-09    Meta                48.97              19.95
# ...          ...     ...                  ...                ...
# 10604 2024-01-12    Meta                99.37             104.28
# 7875  2016-07-23    Meta                53.76              23.97
# 8026  2016-12-21    Meta                53.18              23.42
# 9964  2022-04-12    Meta                84.90              71.99
# 10785 2024-07-11    Meta               100.78             102.92
#
#        AI_Revenue_Growth_%                            Event  Stock_Impact_%  \
# 10731               415.23      LLaMA 3 release (predicted)            7.40
# 10426               328.37                  LLaMA 2 release            6.80
# 10282               334.89                  LLaMA 1 release            6.10
# 9156                145.49                  Cloud AI launch            4.86
# 7526                 -0.27  AI Video Recommendation upgrade            4.80
# ...                    ...                              ...             ...
# 10604               421.42  AI Video Recommendation upgrade           -2.75
# 7875                 19.83         AI-powered search update           -2.79
# 8026                 17.11         AI-powered search update           -2.82
# 9964                259.95          AI ethics policy update           -2.83
# 10785               414.60          AI ethics policy update           -2.99
#
#        Year Month_Name
# 10731  2024        May
# 10426  2023       July
# 10282  2023   February
# 9156   2020    January
# 7526   2015     August
# ...     ...        ...
# 10604  2024    January
# 7875   2016       July
# 8026   2016   December
# 9964   2022      April
# 10785  2024       July
#
# [3653 rows x 9 columns]

# %%
df.to_csv("finalcleaneddata.csv", index=False)

print("Cleaned data saved successfully as 'finalcleaneddata.csv'")
# Out:
# Cleaned data saved successfully as 'finalcleaneddata.csv'
